# %%
source_dir = "/Volumes/event-driven/default/event-driven-pipeline/source/"
target_dir = "/Volumes/event-driven/default/event-driven-pipeline/archive/"
stage_table = "`event-driven`.`default`.`orders_stage`"

# %%
df = spark.read.csv(source_dir, header=True, inferSchema=True)

# %%
df.write.format("delta").mode("overwrite").saveAsTable(stage_table)

# %%
# List all files in the source directory
files = dbutils.fs.ls(source_dir)

# Iterate on the list one by one and print each file path separately
for file in files:
    src_path = file.path

    # Construct the target path
    target_path = target_dir + src_path.split("/")[-1]
    
    # Move the file
    dbutils.fs.mv(src_path, target_path)
